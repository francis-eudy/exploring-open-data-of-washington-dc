# %%
import json
import pandas as pd
# Pandas Options 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
import urllib3
from urllib3 import request
import certifi

# %%
# Define Url with CSV

moving_violations_issued_in_march_2021 = 'https://opendata.arcgis.com/datasets/660ac078bea649e2a9a1c32abbff1059_2.csv'

# %%
# Read into pandas dataframe

df = pd.read_csv(moving_violations_issued_in_march_2021)
df.head()
# Out:
# /opt/conda/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    OBJECTID                     LOCATION  XCOORD  YCOORD  \
# 0  12006949     1800 INDEPENDENCE AVE SW     NaN     NaN
# 1  12006950   INBOUND MEMORIAL BRIDGE SW     NaN     NaN
# 2  12006951     OUTBOUND MEMORIAL BRIDGE     NaN     NaN
# 3  12006952     17TH/INDEPENDENCE AVE SW     NaN     NaN
# 4  12006953  W BEACH/INDEPENDENCE AVE SW     NaN     NaN
#
#                ISSUE_DATE  ISSUE_TIME  ISSUING_AGENCY_CODE  \
# 0  2021/03/16 04:00:00+00         NaN                   22
# 1  2021/03/21 04:00:00+00         NaN                   22
# 2  2021/03/21 04:00:00+00         NaN                   22
# 3  2021/03/24 04:00:00+00         NaN                   22
# 4  2021/03/27 04:00:00+00         NaN                   22
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97078 entries, 0 to 97077
# Data columns (total 33 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   OBJECTID                97078 non-null  int64
#  1   LOCATION                97078 non-null  object
#  2   XCOORD                  81213 non-null  float64
#  3   YCOORD                  81213 non-null  float64
#  4   ISSUE_DATE              97078 non-null  object
#  5   ISSUE_TIME              0 non-null      float64
#  6   ISSUING_AGENCY_CODE     97078 non-null  int64
#  7   ISSUING_AGENCY_NAME     97078 non-null  object
#  8   ISSUING_AGENCY_SHORT    97078 non-null  object
#  9   VIOLATION_CODE          97078 non-null  object
#  10  VIOLATION_PROCESS_DESC  97078 non-null  object
#  11  PLATE_STATE             97078 non-null  object
#  12  ACCIDENT_INDICATOR      2957 non-null   object
#  13  DISPOSITION_CODE        1715 non-null   float64
# ...

# %%
agencies = df.groupby(['ISSUING_AGENCY_CODE', 'ISSUING_AGENCY_NAME', 'ISSUING_AGENCY_SHORT']).size()
agencies
# Out:
# ISSUING_AGENCY_CODE  ISSUING_AGENCY_NAME                  ISSUING_AGENCY_SHORT
# 1                    METROPOLITAN POLICE DPT-DISTRICT 1   MPD-1D                    378
# 2                    METROPOLITAN POLICE DPT-DISTRICT 2   MPD-2D                    820
# 3                    METROPOLITAN POLICE DPT-DISTRICT 3   MPD-3D                    456
# 4                    METROPOLITAN POLICE DPT-DISTRICT 4   MPD-4D                    149
# 5                    METROPOLITAN POLICE DPT-DISTRICT 5   MPD-5D                    239
# 6                    METROPOLITAN POLICE DPT-DISTRICT 6   MPD-6D                    542
# 7                    METROPOLITAN POLICE DPT-DISTRICT 7   MPD-7D                    139
# 16                   TAXI COMMISSION                      DCTC                        2
# 21                   MPD RESERVE CORPS                    MPD-RC                     10
# 22                   UNITED STATES PARK POLICE            USPP                      108
# ...

# %%
violations = df.groupby(['VIOLATION_CODE', 'VIOLATION_PROCESS_DESC']).size()
violations
# Out:
# VIOLATION_CODE  VIOLATION_PROCESS_DESC
# T005            FAIL TO HAVE LICENSE                                     32
# T008            COLLIDING WITH FIXED OBJECT W/NO DAMAGE OR INJURY        12
# T011            FAIL TO YIELD TO PEDESTRIAN AT NON-SIGNALIZED SITE        3
# T013            FAIL TO PAY ATTENTION WHILE OPERATING A VEHICLE         121
# T018            BACK UP WITHOUT CAUTION                                   7
# T035            INTERFERE WITH TRAFFIC WHEN PULLING FROM CURB             1
# T038            ENTER A BLOCK WITH FIRE APPARATUS PRESENT                 2
# T040            FOLLOW WITHIN FIVE HUNDRED FEET OF FIRE APPARATUS         1
# T043            FOLLOW A VEHICLE TOO CLOSELY                             37
# T050            OPERATE UNREGISTERED MOTOR DRIVEN CYCLE                   2
# T051            DRIVE OVER A SIDEWALK                                     7
# T058            FAIL TO KEEP IN LANE                                     27
# ...

# %%
df['DISPOSITION_TYPE'].value_counts()
# Out:
# Other             95363
# Liable             1340
# Dismissed           334
# Continued            40
# Administrative        1
# Name: DISPOSITION_TYPE, dtype: int64

# %%
df['FINE_AMOUNT'].value_counts()
# Out:
# 100     68386
# 150     15358
# 200      8604
# 300      1806
# 500       807
# 400       768
# 50        599
# 30        260
# 25        259
# 800       125
# 75         75
# 15          9
# 35          8
# 250         6
# 20          3
# 1100        2
# 125         2
# 1000        1
# Name: FINE_AMOUNT, dtype: int64

# %%
df['TOTAL_PAID'].value_counts()
# Out:
#  0      77187
#  100    14860
#  150     2950
#  200     1404
#  300      268
#  50       135
#  400      118
#  25        58
#  500       35
#  30        26
#  75        14
#  800        6
#  70         4
# -100        2
#  250        2
#  60         1
# -200        1
#  120        1
#  40         1
#  240        1
#  110        1
#  45         1
#  15         1
#  125        1
# Name: TOTAL_PAID, dtype: int64

# %%
df['PLATE_STATE'].value_counts()
# Out:
#       94140
# MD     1082
# VA      771
# DC      748
# NC       36
# TX       34
# UN       31
# FL       28
# NO       21
# DE       20
# NJ       16
# NY       16
# PA       16
# GA       15
# OH       12
# WV        9
# XX        8
# SC        7
# US        7
# MA        6
# TN        6
# IN        6
# IL        5
# AL        4
# NH        3
# YY        3
# MO        3
# MI        3
# ON        2
# NM        2
# MR        2
# MN        2
# AR        2
# AK        1
# QC        1
# WI        1
# ND        1
# WY        1
# ME        1
# AZ        1
# VT        1
# NE        1
# MT        1
# LA        1
# CT        1
# Name: PLATE_STATE, dtype: int64

# %%
locations = df.groupby(['LOCATION', 'XCOORD', 'YCOORD']).size()
locations
# Out:
# LOCATION                             XCOORD      YCOORD
# 100  NEW YORK AVE NW                 398891.130  137577.220       1
# 100 BLK IRVING ST NW W/B             398820.990  140084.440     301
# 100 BLK MICHIGAN AVE NW E/B          398728.300  139835.900    1197
# 1000 SOUTHERN AVE SE                 401169.780  129438.371       2
# 1040 SOUTHERN AVE SE                 401188.510  129495.200       2
# 1093 3RD ST NE                       399823.060  137251.900       1
# 1100 BLK BLADENSBURG RD NE NE/B      401644.780  137368.360     503
# 1100 BLK MICHIGAN AVE NE W/B         400625.080  141135.230     211
# 1101 HOWARD RD SE                    400414.110  132706.810       1
# 1118 PEABODY ST NW                   397537.800  143866.030       1
# 11TH ST N/B @ LAMONT ST NW           397573.070  140312.980      36
# 1200 BLADENSBURG RD NE               401708.370  137538.140       1
# 1200 BLK TAYLOR ST NE E/B            400888.740  141426.060       3
# ...
